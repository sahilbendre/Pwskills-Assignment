# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is a web framework. Flask allows you to build a web application by providing tools, libraries, and technologies. This web application will be a web page or a big web-based calendar application or commercial website. Flask is classified into a micro-framework that means it has little to no dependencies on external libraries. There are some pros and cons. Pros mean there are little dependencies to upgrade and to watch security bugs and cons means by adding the plugin you will increase the dependencies.
#
# __Advantages of Flask Framework__:
# Lightweight: Flask is a lightweight framework and is easy to install.
#
# Flexibility: Flask allows developers to use any database, template engine, or other libraries as per their choice.
#
# Easy to learn: Flask is beginner-friendly and easy to understand. You can quickly build and deploy small web applications with Flask.
#
# Extensible: Flask is highly extensible and can integrate with multiple Python libraries.
#
# Scalable: Flask can easily handle a large number of users and database records. It can scale up as per the application's needs.
#
# Integrated Unit Testing: Flask offers an integrated unit testing feature that helps in faster debugging, robust development, and independence to do experiments.

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %%
pip install flask
# Out:
# ...
#
# ...

# %%
from flask import Flask
app = Flask(__name__)

@app.route('/')
def hello_world():
    return "<h3>Hello World</h3>"
if __name__ == "__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.43.192:5000/ (Press CTRL+C to quit)

# %% [markdown]
# ![Screenshot%202023-06-09%20124219.png](attachment:Screenshot%202023-06-09%20124219.png)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# App routing in Flask is the process of mapping URLs to specific functions or views in a Flask application. It allows the application to handle different requests from clients and return appropriate responses.
#
# We use app routes in Flask to define the behavior of our application when a user visits a specific URL. By defining routes, we can create different pages or endpoints within our application that serve different purposes. For example, we can define a route for the homepage, a route for user login, and a route for displaying user data.

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999
# Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask
app=Flask(__name__)

@app.route('/')
def main_page():
    return"<h3>Company Name: ABC Corporation <br>Location: India <br> Contact Detail: 999-999-9999 </h3>"

@app.route('/welcome')
def welcome_page():
    return "<h2>Welcome to ABC Corporation</h2>"

if __name__=="__main__":
    app.run(port = 8080)

# %% [markdown]
# ![Screenshot%202023-06-09%20133011.png](attachment:Screenshot%202023-06-09%20133011.png)

# %% [markdown]
# ![Screenshot%202023-06-09%20133150.png](attachment:Screenshot%202023-06-09%20133150.png)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function?

# %% [markdown]
# In Flask, the url_for() function is used for URL building. It generates a URL for a specific endpoint based on the endpoint name and any parameters passed to it.

# %%
from flask import Flask
app=Flask(__name__)

@app.route('/')
def first_page():
    return "<h2>Welcome To Abs Corporation</h2>"
if __name__=="__main__":
    app.run(port = 7000)

# %% [markdown]
# ![Screenshot%202023-06-09%20133339.png](attachment:Screenshot%202023-06-09%20133339.png)
