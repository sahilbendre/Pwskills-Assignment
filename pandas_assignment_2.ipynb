# %% [markdown]
# Q1. List any five functions of the pandas library with execution?

# %% [markdown]
# 1. pd.read_csv, pd.read_excel

# %% [markdown]
# This function used to read the csv or excel.till we used at least one of these functions in every project.The functions are self-explanatory .They are used to read a CSV or an excel file to a pandas DataFrame format.

# %%
import pandas as pd
df=pd.read_csv("services.csv")

# %% [markdown]
# 2. head()

# %% [markdown]
# It is use .head() function after read_csv or read_excel to see the data frame. By default, it shows the first 5 rows of the DataFrame. Here I am showing the first five rows of the DataFrame df above:

# %%
df.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %% [markdown]
# 3. Columns()

# %% [markdown]
# When you have a big dataset like that it can be hard to see all the columns. using .columns function, you can print out all the columns of the dataset.

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %% [markdown]
# 3. drop()

# %% [markdown]
# You can drop some unnecessary columns using df.drop().In this dataset we have so many columns we are not going to use all of them for this example. So, we can easily drop some

# %%
df.drop(columns=["program_id","accepted_payments","alternate_name"])
# Out:
#     id  location_id                                application_process  \
# 0    1            1                         Walk in or apply by phone.
# 1    2            2                 Apply by phone for an appointment.
# 2    3            3        Phone for information (403-4300 Ext. 4322).
# 3    4            4                                    Apply by phone.
# 4    5            5                             Phone for information.
# 5    6            6  Walk in or apply by phone for membership appli...
# 6    7            7  Apply by phone or be referred by a doctor, soc...
# 7    8            8                                    Apply by phone.
# 8    9            9  Walk in. Proof of residency in California requ...
# 9   10           10  Walk in. Proof of California residency to rece...
# 10  11           11  Walk in. Proof of California residency require...
# 11  12           12  Walk in or apply by phone, email or webpage re...
# ...

# %% [markdown]
# 4. dtypes

# %% [markdown]
# Another very basic and widely used functions. Because it is necessary to know the data types of the variables before we dive into the analysis, visualization, or predictive modeling.

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %% [markdown]
# 5. groupby()

# %% [markdown]
# This is the most popular function for data summarizing. You can group the data as per a certain variable and find out useful information about those groups.

# %%
g=df.groupby('email')

# %%
g.sum()
# Out:
# /tmp/ipykernel_123/1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#                        id  location_id  program_id
# email
# passports@example.org  22           22         0.0

# %% [markdown]
# Q2.Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the
# DataFrame with a new index that starts from 1 and increments by 2 for each row?

# %%
data={"A":[1,89,9,5,3,5],
      "B":[7,8,9,96,3,5],
      "c":[5,6,1,4,63,4]}
df2=pd.DataFrame(data)
df2
# Out:
#     A   B   c
# 0   1   7   5
# 1  89   8   6
# 2   9   9   1
# 3   5  96   4
# 4   3   3  63
# 5   5   5   4

# %%
new_index=list(range(1,2*len(df2),2))

# %%
new_index
# Out:
# [1, 3, 5, 7, 9, 11]

# %%
df2.index=new_index

# %% [markdown]
# df2

# %% [markdown]
# Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that
# iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The
# function should print the sum to the console.
#
# For example, if the 'Values' column of df contains the values [10, 20, 30, 40, 50], your function should
# calculate and print the sum of the first three values, which is 60

# %%
values=[10, 20, 30, 40, 50]
df1=pd.DataFrame(values)
df1.rename(columns = {0:'values'}, inplace = True)
df1
# Out:
#    values
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50

# %%
def sum_values(x):
    sum=0
    count_v=0
    for i in x["values"]:
        sum =sum + i
        count_v+=1
        if count_v == 3:
            break
    return sum
sum_values(df1)
# Out:
# 60

# %% [markdown]
# Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column
# 'Word_Count' that contains the number of words in each row of the 'Text' column

# %%
data={"text":["sam is good boy","dipesh is hard work person","sham is a data analytics","Amazon is best e-commerce website","Pwskill is a Education website"]}
df2=pd.DataFrame(data)
def word_count(x):
    count=len(x.split(" "))
    return count

df2["Word Count"]=df2["text"].apply(word_count)
df2
# Out:
#                                 text  Word Count
# 0                    sam is good boy           4
# 1         dipesh is hard work person           5
# 2           sham is a data analytics           5
# 3  Amazon is best e-commerce website           5
# 4     Pwskill is a Education website           5

# %% [markdown]
# Q5. How are DataFrame.size() and DataFrame.shape() different?

# %% [markdown]
# Size and shape of a dataframe in pandas python:
#
# Size of a dataframe is the number of fields in the dataframe which is nothing but number of rows * number of columns.
#
# Shape of a dataframe gets the number of rows and number of columns of the dataframe.

# %%
df2.size
# Out:
# 10

# %%
df2.shape
# Out:
# (5, 2)

# %% [markdown]
# Q6.Which function of pandas do we use to read an excel file?

# %% [markdown]
# We use pandas.read_excel() funtion to read the excel file.

# %% [markdown]
# Q7.You have a Pandas DataFrame df that contains a column named 'Email' that contains email addresses in the format 'username@domain.com'. Write a Python function that creates a new column 'Username' in df that contains only the username part of each email address.
#
# The username is the part of the email address that appears before the '@' symbol. For example, if the email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your function should extract the username from each email address and store it in the new 'Username' column.

# %%
df=pd.DataFrame({"email":[ 'john.doe@example.com',"rohny@gmail.com","Samir122@gk.com","jamespeter2@go,com","jimmy2212@S.com"]})

# %%
def username(email):
    username1=[]
    for i in email:
        names=i.split('@')
        username1.append(names[0])
    return username1

# %%
df["usename"]=username(df["email"])

# %%
df
# Out:
#                   email      usename
# 0  john.doe@example.com     john.doe
# 1       rohny@gmail.com        rohny
# 2       Samir122@gk.com     Samir122
# 3    jamespeter2@go,com  jamespeter2
# 4       jimmy2212@S.com    jimmy2212

# %% [markdown]
# @8.You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The function should return a new DataFrame that contains only the selected rows.

# %%
df=pd.DataFrame({"A":[1,2,5,6,7,9],
                "B":[7,9,6,3,211,4],
                "C":[55,445,224,5,6,2]})

# %%
df
# Out:
#    A    B    C
# 0  1    7   55
# 1  2    9  445
# 2  5    6  224
# 3  6    3    5
# 4  7  211    6
# 5  9    4    2

# %%
def new_df(df):
    i=0
    index=[]
    for ele_A ,ele_B in zip(df["A"],df["B"]):
        if ele_A>5 and ele_B<10:
            index.append(i)
        i+=1
    new_df = df.loc[index]
    return new_df

# %%
l=new_df(df)

# %%
l
# Out:
#    A  B  C
# 3  6  3  5
# 5  9  4  2

# %% [markdown]
# Q9.Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean, median, and standard deviation of the values in the 'Values' column.

# %%
df1=pd.DataFrame({"values":[57,89,45,3,1,2]})
df1
# Out:
#    values
# 0      57
# 1      89
# 2      45
# 3       3
# 4       1
# 5       2

# %%
def calc(x):
    mean=x["values"].mean()
    median=x["values"].median()
    stde=x["values"].std()
    
    return mean,median,stde
mean,median,stde=calc(df1)
print(f"means:{mean},median:{median} and Standard Deviation:{stde}")
# Out:
# means:32.833333333333336,median:24.0 and Standard Deviation:36.717389159179966

# %% [markdown]
# Q10.Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days for each row in the DataFrame. The moving average should be calculated using a window of size 7 and should include the current day.

# %%
data = {'Sales': [2.1, 2.2, 3.3, 4.4, 5.5,1.1, 2.2,5.1,5.6,2.2]}

df = pd.DataFrame(data)
df.head()
# Out:
#    Sales
# 0    2.1
# 1    2.2
# 2    3.3
# 3    4.4
# 4    5.5

# %%
def moving_average(df):
    df['MovingAverage'] = df['Sales'].rolling(window=7, min_periods=1).mean()
    return df
df_col = moving_average(df)
df_col
# Out:
#    Sales  MovingAverage
# 0    2.1       2.100000
# 1    2.2       2.150000
# 2    3.3       2.533333
# 3    4.4       3.000000
# 4    5.5       3.500000
# 5    1.1       3.100000
# 6    2.2       2.971429
# 7    5.1       3.400000
# 8    5.6       3.885714
# 9    2.2       3.728571

# %% [markdown]
# Q11.You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g. Monday, Tuesday) corresponding to each date in the 'Date' column.

# %%
df3=pd.DataFrame({"date":['2023-01-01','2023-01-02','2023-01-03','2023-01-04','2023-01-05', '2023-01-06']})
df3
# Out:
#          date
# 0  2023-01-01
# 1  2023-01-02
# 2  2023-01-03
# 3  2023-01-04
# 4  2023-01-05
# 5  2023-01-06

# %%
def weekday(df):
    weekdays=[]
    for i in df["date"]:
        temp=i.split("-")
        if temp[2]=="01":
            weekdays.append('Sunday')
        elif temp[2]=="02":
            weekdays.append('Munday')
        elif temp[2]=="03":
            weekdays.append('Tuseday')
        elif temp[2]=="04":
            weekdays.append('Wednesday')
        elif temp[2]=="05":
            weekdays.append('Thusday')
        elif temp[2]=="06":
            weekdays.append('Friday') 
        else:
            weekdays.append('Saturday')
    df["Weekday"]=weekdays            
    return df

# %%
weekday(df3)
# Out:
#          date    Weekday
# 0  2023-01-01     Sunday
# 1  2023-01-02     Munday
# 2  2023-01-03    Tuseday
# 3  2023-01-04  Wednesday
# 4  2023-01-05    Thusday
# 5  2023-01-06     Friday

# %% [markdown]
# Q12.Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python function to select all rows where the date is between '2023-01-01' and '2023-01-31'?

# %%
df3=pd.DataFrame({"date":['2023-01-01','2023-01-02','2023-01-03','2023-01-04','2023-01-05', '2023-01-06']})
df3
# Out:
#          date
# 0  2023-01-01
# 1  2023-01-02
# 2  2023-01-03
# 3  2023-01-04
# 4  2023-01-05
# 5  2023-01-06

# %%
def selected_dates(df):
    start_date = '2023-01-03'
    end_date = '2023-01-05'
    mask = (df['date'].dt.date >= pd.to_datetime(start_date).date()) & (df['Date'].dt.date <= pd.to_datetime(end_date).date())

    return df.loc[mask]
df3['date'] = pd.to_datetime(df3['date'])

new_data = selected_dates(df3)
new_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df3
# Out:
#          date
# 0  2023-01-01
# 1  2023-01-02
# 2  2023-01-03
# 3  2023-01-04
# 4  2023-01-05
# 5  2023-01-06

# %% [markdown]
# Q13.To use the basic functions of pandas, what is the first and foremost necessary library that needs to be imported?

# %% [markdown]
# The first and foremost necessary library that needs to be imported to use the basic functions of Pandas is the Pandas library itself.
